# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.linear_model import LinearRegression 
from sklearn.neighbors import KNeighborsRegressor


from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# ## Problem statement

# %% [raw]
# Prediction of Graduate Admissions from an Indian perspective.
#
# Content
# Dataset contains under given important parameters which are considered mainly during application for Masters Programs.
# Parameters description:
#
# #Following are the input features:
# GRE Scores ( out of 340 )
# TOEFL Scores ( out of 120 )
# University Rating ( out of 5 )
# Statement of Purpose -(SOP) Strength ( out of 5 )
# Letter of Recommendation-(LOR) Strength ( out of 5 )
# Undergraduate GPA-CGPA ( out of 10 )
# Research Experience ( either 0 or 1 )
#
# # Following is the target feature
# Chance of Admit ( ranging from 0 to 1 )
#
# Inspiration
# Results will help students in shortlisting universities with their profiles.
# Predicted output can provide students a fair idea about their chances for a particular university.
#
# Following are the input features

# %% [markdown]
# ## Data Gathering

# %%
df=pd.read_csv("admission_data.csv")
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
df.isna().value_counts()
# Out:
# GRE Score  TOEFL Score  University Rating  SOP    LOR    CGPA   Research  Chance of Admit
# False      False        False              False  False  False  False     False               500
# dtype: int64

# %%
x=df.drop('Chance of Admit ',axis=1)
y=df['Chance of Admit ']

# %% [markdown]
# ## EDA

# %%
df=pd.read_csv("admission_data.csv")
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
df.isna().sum()  #NO NULL VALUES ARE PRESENT
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.info()    #ALL THE FEATURES CONTAINS NUMERIC VALUES
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# #### 1.GRE Score

# %%
df['GRE Score']
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 495    332
# 496    337
# 497    330
# 498    312
# 499    327
# Name: GRE Score, Length: 500, dtype: int64

# %%
sns.kdeplot(df['GRE Score'])
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='Density'>

# %% [markdown]
# #### 2.TOEFL Score

# %%
sns.kdeplot(df['TOEFL Score'])
# Out:
# <AxesSubplot:xlabel='TOEFL Score', ylabel='Density'>

# %% [markdown]
# #### 3.University Rating

# %%
sns.kdeplot(df["University Rating"])
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='Density'>

# %% [markdown]
# #### 4.SOP

# %%
sns.kdeplot(df["SOP"])
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='Density'>

# %% [markdown]
# #### 5.LOR

# %%
sns.kdeplot(df['LOR '])
# Out:
# <AxesSubplot:xlabel='LOR ', ylabel='Density'>

# %% [markdown]
# #### 6.CGPA

# %%
sns.kdeplot(df['CGPA'])
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# #### 7.Research

# %%
min(df["esearch"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'research'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sns.kdeplot(df["Research"])
# Out:
# <AxesSubplot:xlabel='Research', ylabel='Density'>

# %%
sns.kdeplot(df['Chance of Admit '])
# Out:
# <AxesSubplot:xlabel='Chance of Admit ', ylabel='Density'>

# %% [markdown]
# ### assumptions

# %% [markdown]
# ##### 1)linearity

# %%
df.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.541563  0.810574  0.467012          0.792228
# University Rating  0.608651  0.705254  0.427047          0.690132
# ...

# %%
sns.pairplot(df)
plt.savefig("pairplot.png")

# %% [markdown]
# ### heatmap

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True)
plt.show()
plt.savefig("heatmap.png")

# %%
sns.histplot(x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### 2.Independence

# %%
df.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.541563  0.810574  0.467012          0.792228
# University Rating  0.608651  0.705254  0.427047          0.690132
# ...

# %% [markdown]
# ## outliers

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### normalization

# %%
#scaling 
#as the features are not normally distributed we are using normalization 
x.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research
# count  500.000000  500.000000
# mean     8.576440    0.560000
# std      0.604813    0.496884
# min      6.800000    0.000000
# 25%      8.127500    0.000000
# 50%      8.560000    1.000000
# 75%      9.040000    1.000000
# max      9.920000    1.000000

# %%
x.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research'],
#       dtype='object')

# %%
norm_scaler=MinMaxScaler()
norm_scaler.fit(x)  # x_min and x_max are calculated 
norm_data=norm_scaler.transform(x)
norm_data
df_norm=pd.DataFrame(norm_data,columns=x.columns)
df_norm
# Out:
#      GRE Score  TOEFL Score  University Rating    SOP   LOR       CGPA  \
# 0         0.94     0.928571               0.75  0.875  0.875  0.913462
# 1         0.68     0.535714               0.75  0.750  0.875  0.663462
# 2         0.52     0.428571               0.50  0.500  0.625  0.384615
# 3         0.64     0.642857               0.50  0.625  0.375  0.599359
# 4         0.48     0.392857               0.25  0.250  0.500  0.451923
# ..         ...          ...                ...    ...    ...       ...
# 495       0.84     0.571429               1.00  0.875  0.750  0.711538
# 496       0.94     0.892857               1.00  1.000  1.000  0.983974
# 497       0.80     1.000000               1.00  0.875  1.000  0.884615
# 498       0.44     0.392857               0.75  0.750  1.000  0.522436
# 499       0.74     0.750000               0.75  0.875  0.875  0.717949
#
#      Research
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         0.0
# ..        ...
# ...

# %% [markdown]
# ## Model Training

# %% [markdown]
# #### linear_regression model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)
x_train.shape,y_train.shape,y_test.shape,x_test.shape
# Out:
# ((375, 7), (375,), (125,), (125, 7))

# %%
lin_model=LinearRegression()

# %%
lin_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lin_model.coef_
# Out:
# array([0.00216508, 0.00331129, 0.00237087, 0.00121341, 0.01705316,
#        0.11682683, 0.024134  ])

# %%
lin_model.intercept_
# Out:
# -1.4041160492611477

# %%
y_pred=lin_model.predict(x_train)

# %%
df.head(1)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
#
#    Chance of Admit
# 0              0.92

# %%
mean_absolute_error(y_train,y_pred)
# Out:
# 0.04251234385111586

# %%
#model evaluation function
def model_eval(model,x,y):
    y_pred=model.predict(x)
    mae=mean_absolute_error(y,y_pred)
    mse=mean_squared_error(y,y_pred)
    R2=r2_score(y,y_pred)
    print(f"mean squared error={mse}")
    print()
    print(f"mean absolute error={mae}")
    print()
    print(f"r 2 score={R2}")
    
    return "evaluation done"

# %%
#model evaluation on training data 
print("#"*50)
print()
print("evaluation of training data")
model_eval(lin_model,x_train,y_train)
print("#"*50)
print()
print("evaluation of testing data")
model_eval(lin_model,x_test,y_test)
# Out:
# ##################################################
#
# evaluation of training data
# mean squared error=0.003550515867188403
#
# mean absolute error=0.04251234385111586
#
# r 2 score=0.8223444375427977
# ##################################################
#
# evaluation of testing data
# mean squared error=0.0035857302916122435
#
# mean absolute error=0.04311184801806067
#
# r 2 score=0.8163213016062121
# 'evaluation done'

# %% [raw]
# lin_model
# #bias and variance tradeoff
# high bias and low variance
#
# model is under fit

# %% [markdown]
# #### KNN REGRESSOR MODEL

# %%
##KNN REGRESSOR MODEL 
knn_model=KNeighborsRegressor(n_neighbors=5,p=2)
knn_model.fit(x,y_train)  ##fitting training data
# Out:
# KNeighborsRegressor()

# %%
model_eval(knn_model,x_train,y_train)
# Out:
# mean squared error=0.003643722666666667
#
# mean absolute error=0.045072
#
# r 2 score=0.8176806909196178
# 'evaluation done'

# %%
print("#"*50)
print()
print("evaluation of training data")
model_eval(knn_model,x_train,y_train)
print("#"*50)
print()
print("evaluation of testing data")
model_eval(knn_model,x_test,y_test)
# Out:
# ##################################################
#
# evaluation of training data
# mean squared error=0.003643722666666667
#
# mean absolute error=0.045072
#
# r 2 score=0.8176806909196178
# ##################################################
#
# evaluation of testing data
# mean squared error=0.005515136
#
# mean absolute error=0.054944
#
# r 2 score=0.7174876748777322
# 'evaluation done'

# %% [raw]
# knn_model
# #bias and variance tradeoff
# high bias and high variance
#
# worst model  ###scaling is required

# %% [markdown]
# #### KNN model with norm data

# %%
#knn_model training with normalised  data
x_train,x_test,y_train,y_test=train_test_split(df_norm,y,random_state=5,test_size=0.3)

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
#model evaluation
print("#"*50)
print()
print("evaluation of training data")
model_eval(knn_model,x_train,y_train)
print("#"*50)
print()
print("evaluation of testing data")
model_eval(knn_model,x_test,y_test)
# Out:
# ##################################################
#
# evaluation of training data
# mean squared error=0.0032334514285714284
#
# mean absolute error=0.04097714285714285
#
# r 2 score=0.850455324724229
# ##################################################
#
# evaluation of testing data
# mean squared error=0.004063519999999999
#
# mean absolute error=0.04525333333333333
#
# r 2 score=0.7429886996120763
# 'evaluation done'

# %% [markdown]
# ### standardization

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
std=StandardScaler()
